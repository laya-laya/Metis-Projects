# %% [markdown]
# # Get the data
# In this notebook the connection strength data will be processed into a nice dataframe to use in other notebooks

# %%
# %matplotlib inline

# %%
from bs4 import BeautifulSoup
from collections import defaultdict, OrderedDict

import numpy as np
import pandas as pd

import os
import re

import pickle as pkl

# %% [markdown]
# ## Get metadata for each subject

# %%
with open("cm_table.html", "r") as f:
    table = f.read()

soup = BeautifulSoup(table, "html.parser")

rows = soup.find_all(class_="powerTable")[1].tbody.find_all("tr")[3:523]

# %%
cols = defaultdict(list)
for row in rows:
    text_list = list(row.stripped_strings)
    if len(text_list) == 13:
        text_list.insert(7, 'na') # insert so list is standard size when that column was empty on the webpage
    cols["study"].append(text_list[2])
    cols["id"].append(text_list[3].replace("_", ""))
    cols["age"].append(float(text_list[8]))
    cols["gender"].append(text_list[10])
    cols["label"].append(text_list[11])

# %%
metadata = pd.DataFrame(cols)

# %%
del cols
del soup
del rows

# %% [markdown]
# ## Load the connectivity matrices

# %%
def get_conn_matrices():
    file_names = os.listdir("data/ADHD200_CC200")

    cm_file_re = r"^\S+connectivity_matrix_file\.txt$"

    conn_matrices = OrderedDict()
    for file_name in file_names:
        if re.match(cm_file_re, file_name):
            id_ = "".join(file_name.split("_")[:-3])
        
            cm = np.empty((190,190))
            with open("data/ADHD200_CC200/{}".format(file_name)) as f:
                for idx, row in enumerate(f):
                    row = row.strip().split(" ")
                    row = list(map(np.float, row))
                    cm[idx, :] = row
            
            less_than_zero_mask = cm < 0 # get indices of values less than zero
            cm[less_than_zero_mask] = 0 # set values less than zero to zero
            
            conn_matrices[id_] = cm
    return conn_matrices

# %%
def get_regions(abbrev=True):
    """
    Gets the names of the regions (in order of appearance in connectivity matrix). 
    All files have the same order of regions, so we only to need to get this once.
    Some region names are repeated because there are multiple points within that region,
        so numbers are appended to the region names to distinguish them.
    
    returns a list of strings
    """
    regions_path = "data/ADHD200_CC200/KKI_1018959_region_names_abbrev_file.txt" if abbrev else "data/ADHD200_CC200/KKI_1018959_region_names_full_file.txt"
    regions = []
    with open(regions_path, "r") as f:
        regions = [region.strip().replace(" ", "_") for region in f]
    names = defaultdict(int)
    distinct_region_names = []
    for region in regions:
        distinct_region_names.append(region+"_"+str(names[region]))
        names[region] += 1
    return distinct_region_names

# %%
region_names = get_regions()

conn_matrices = get_conn_matrices()

# %% [markdown]
# ## data prep

# %%
def flatten_conn_matrices(conn_matrices_dict, region_names):
    """
    Flatten a cm dictionary (mapping subjects to connectivity matrices), such that each unique value in the
        connectivity matrix is a column feature in a row.
    Returns: 1) a numpy array where each row represents a subject with each column a feature;
             2) a list of the subject ids in the order they appear in the feature array;
             3) a list of the feature names in the order they appear in the feature array.
    The subjects list holds the row labels, feature_names list holds column labels.
    """
    subjects = list(conn_matrices_dict.keys())
    num_rows = len(subjects)
    features = np.empty((num_rows, 17955))
    
    # adjacency matrices have duplicate values, only need values from half of the matrix (and don't need diagonal)
    # np.tril_indices() returns indices of unique values
    row_idxs, col_idxs = np.tril_indices(190, k=-1)
    for idx, subject in enumerate(subjects):
        cm = conn_matrices_dict[subject]
        row = np.array([cm[row_idx, col_idx] for row_idx, col_idx in zip(row_idxs, col_idxs)])
        features[idx, :] = row
    
    feature_names = [region_names[row_idx]+"_to_"+region_names[col_idx] 
                     for row_idx, col_idx in zip(row_idxs, col_idxs)]
    
    return features, subjects, feature_names

# %%
features, subjects, feature_names = flatten_conn_matrices(conn_matrices, region_names)

# %%
# free up some memory
del conn_matrices

# %%
def sort_metadata(metadata, subjects):
    """
    Sorts a metadata dataframe so that the order is the same as the order of subjects in the subjects list.
    :arg metadata: dataframe with ADHD200 metadata
    :arg subjects: a list of subjects of specific order
    """
    metadata_ids = metadata["id"].values
    subjects_order_in_metadata = [np.where(metadata_ids==subject)[0][0] for subject in subjects]
    metadata_subject_sort = metadata.iloc[subjects_order_in_metadata, :]
    return metadata_subject_sort

# %%
# sort the metadata so that the order is the same as in the feature matrix
metadata_sorted = sort_metadata(metadata, subjects).reset_index()

# %%
del metadata

# %%
# add one hot vectors for each of the ADHD labels
adhd = [0 if label == "Typically Developing" else 1 for label in metadata_sorted["label"]]
metadata_sorted = metadata_sorted.assign(adhd=adhd)
metadata_sorted.drop(columns="label", inplace=True)

# %%
# check to make sure the metadata and feature table are in the same order (subjects is the order of features)
# list(zip(list(metadata_sorted["id"]), subjects))
# Out:
# [('NYU1567356', 'NYU1567356'),
#  ('Peking12106109', 'Peking12106109'),
#  ('Peking23562883', 'Peking23562883'),
#  ('Peking11139030', 'Peking11139030'),
#  ('NYU0010080', 'NYU0010080'),
#  ('Peking24221029', 'Peking24221029'),
#  ('NeuroIMAGE7339173', 'NeuroIMAGE7339173'),
#  ('NYU0010095', 'NYU0010095'),
#  ('NYU4079254', 'NYU4079254'),
#  ('KKI2768273', 'KKI2768273'),
#  ('Pittsburgh0016069', 'Pittsburgh0016069'),
#  ('Pittsburgh0016067', 'Pittsburgh0016067'),
#  ('Peking14053836', 'Peking14053836'),
#  ('Peking23856956', 'Peking23856956'),
#  ('KKI2641332', 'KKI2641332'),
#  ('NYU0010029', 'NYU0010029'),
#  ('Peking23248920', 'Peking23248920'),
#  ('Peking21643780', 'Peking21643780'),
#  ('Peking22207418', 'Peking22207418'),
#  ('NeuroIMAGE2756846', 'NeuroIMAGE2756846'),
#  ('NYU0010032', 'NYU0010032'),
#  ('NYU3845761', 'NYU3845761'),
#  ('Pittsburgh0016056', 'Pittsburgh0016056'),
#  ('Pittsburgh0016058', 'Pittsburgh0016058'),
#  ('KKI8337695', 'KKI8337695'),
#  ('NeuroIMAGE8991934', 'NeuroIMAGE8991934'),
#  ('Peking13390312', 'Peking13390312'),
#  ('NYU0010065', 'NYU0010065'),
#  ('Pittsburgh0016001', 'Pittsburgh0016001'),
#  ('NYU3243657', 'NYU3243657'),
#  ('NYU2735617', 'NYU2735617'),
#  ('NYU0010113', 'NYU0010113'),
#  ('NeuroIMAGE3007585', 'NeuroIMAGE3007585'),
#  ('KKI1686265', 'KKI1686265'),
#  ('Pittsburgh0016082', 'Pittsburgh0016082'),
#  ('NYU0010108', 'NYU0010108'),
#  ('Pittsburgh0016014', 'Pittsburgh0016014'),
#  ('NeuroIMAGE3858891', 'NeuroIMAGE3858891'),
#  ('NeuroIMAGE1208586', 'NeuroIMAGE1208586'),
#  ('NYU3349205', 'NYU3349205'),
#  ('NYU0010070', 'NYU0010070'),
#  ('Peking22601519', 'Peking22601519'),
#  ('NYU0010054', 'NYU0010054'),
#  ('Peking11947991', 'Peking11947991'),
#  ('NYU2854839', 'NYU2854839'),
#  ('NYU0010122', 'NYU0010122'),
#  ('Peking18328877', 'Peking18328877'),
#  ('NYU3518345', 'NYU3518345'),
#  ('Peking23691107', 'Peking23691107'),
#  ('NeuroIMAGE1588809', 'NeuroIMAGE1588809'),
#  ('NYU1700637', 'NYU1700637'),
#  ('Peking25993008', 'Peking25993008'),
#  ('NeuroIMAGE1312097', 'NeuroIMAGE1312097'),
#  ('NYU0010041', 'NYU0010041'),
#  ('NYU2136051', 'NYU2136051'),
#  ('Peking22140063', 'Peking22140063'),
#  ('NYU0010073', 'NYU0010073'),
#  ('Peking22310449', 'Peking22310449'),
#  ('Peking22950754', 'Peking22950754'),
#  ('Pittsburgh0016081', 'Pittsburgh0016081'),
#  ('Pittsburgh0016019', 'Pittsburgh0016019'),
#  ('KKI1638334', 'KKI1638334'),
#  ('KKI2360428', 'KKI2360428'),
#  ('Pittsburgh0016002', 'Pittsburgh0016002'),
#  ('Peking14383707', 'Peking14383707'),
#  ('Peking19783279', 'Peking19783279'),
#  ('NYU0010110', 'NYU0010110'),
#  ('KKI6346605', 'KKI6346605'),
#  ('NYU0010068', 'NYU0010068'),
#  ('NYU2730704', 'NYU2730704'),
#  ('Peking11302449', 'Peking11302449'),
#  ('Peking13707771', 'Peking13707771'),
#  ('KKI4601682', 'KKI4601682'),
#  ('KKI1623716', 'KKI1623716'),
#  ('Peking28278680', 'Peking28278680'),
#  ('Peking16187322', 'Peking16187322'),
#  ('KKI2703289', 'KKI2703289'),
#  ('NYU0010042', 'NYU0010042'),
#  ('Peking13672854', 'Peking13672854'),
#  ('KKI7129258', 'KKI7129258'),
#  ('KKI8432725', 'KKI8432725'),
#  ('Peking23610134', 'Peking23610134'),
#  ('NYU3174224', 'NYU3174224'),
#  ('NYU0010121', 'NYU0010121'),
#  ('Pittsburgh0016033', 'Pittsburgh0016033'),
#  ('NeuroIMAGE3322144', 'NeuroIMAGE3322144'),
#  ('NeuroIMAGE2876903', 'NeuroIMAGE2876903'),
#  ('NYU0010057', 'NYU0010057'),
#  ('Peking22659769', 'Peking22659769'),
#  ('NYU0010059', 'NYU0010059'),
#  ('Peking23194757', 'Peking23194757'),
#  ('Peking22033178', 'Peking22033178'),
#  ('Peking11686092', 'Peking11686092'),
#  ('Pittsburgh0016064', 'Pittsburgh0016064'),
#  ('KKI1692275', 'KKI1692275'),
#  ('Peking14334113', 'Peking14334113'),
#  ('Peking19221927', 'Peking19221927'),
#  ('KKI4104523', 'KKI4104523'),
#  ('NYU3457975', 'NYU3457975'),
#  ('NYU0010083', 'NYU0010083'),
#  ('Peking11912810', 'Peking11912810'),
#  ('NYU1992284', 'NYU1992284'),
#  ('NeuroIMAGE3808273', 'NeuroIMAGE3808273'),
#  ('Pittsburgh0016071', 'Pittsburgh0016071'),
#  ('Peking11875711', 'Peking11875711'),
#  ('Peking11113498', 'Peking11113498'),
#  ('NYU4562206', 'NYU4562206'),
#  ('Pittsburgh0016055', 'Pittsburgh0016055'),
#  ('KKI3519022', 'KKI3519022'),
#  ('NYU1737393', 'NYU1737393'),
#  ('NYU1934623', 'NYU1934623'),
#  ('Peking19093997', 'Peking19093997'),
#  ('Peking13593327', 'Peking13593327'),
#  ('NYU0010031', 'NYU0010031'),
#  ('NYU0010024', 'NYU0010024'),
#  ('NYU1127915', 'NYU1127915'),
#  ('Peking13809753', 'Peking13809753'),
#  ('NeuroIMAGE3941358', 'NeuroIMAGE3941358'),
#  ('NYU3163200', 'NYU3163200'),
#  ('Peking14256491', 'Peking14256491'),
#  ('KKI2371032', 'KKI2371032'),
#  ('Pittsburgh0016035', 'Pittsburgh0016035'),
#  ('NYU0010129', 'NYU0010129'),
#  ('Peking15600820', 'Peking15600820'),
#  ('KKI2640795', 'KKI2640795'),
#  ('Peking22529026', 'Peking22529026'),
#  ('NYU1187766', 'NYU1187766'),
#  ('KKI2903997', 'KKI2903997'),
#  ('Peking29640133', 'Peking29640133'),
#  ('Peking21094669', 'Peking21094669'),
#  ('NYU0010051', 'NYU0010051'),
#  ('KKI1873761', 'KKI1873761'),
#  ('Peking27011503', 'Peking27011503'),
#  ('Peking11469171', 'Peking11469171'),
#  ('Peking24053388', 'Peking24053388'),
#  ('NYU0010044', 'NYU0010044'),
#  ('KKI2618929', 'KKI2618929'),
#  ('NYU5164727', 'NYU5164727'),
#  ('NYU3011311', 'NYU3011311'),
#  ('NYU3650634', 'NYU3650634'),
#  ('NYU8697774', 'NYU8697774'),
#  ('KKI1019436', 'KKI1019436'),
#  ('KKI2554127', 'KKI2554127'),
#  ('Pittsburgh0016020', 'Pittsburgh0016020'),
#  ('NYU0010116', 'NYU0010116'),
#  ('NYU2570769', 'NYU2570769'),
#  ('NYU0010118', 'NYU0010118'),
#  ('KKI4362730', 'KKI4362730'),
#  ('Pittsburgh0016004', 'Pittsburgh0016004'),
#  ('KKI2822304', 'KKI2822304'),
#  ('Peking12249443', 'Peking12249443'),
#  ('Peking21159908', 'Peking21159908'),
#  ('NYU0010075', 'NYU0010075'),
#  ('NeuroIMAGE3980079', 'NeuroIMAGE3980079'),
#  ('Pittsburgh0016089', 'Pittsburgh0016089'),
#  ('Peking23446674', 'Peking23446674'),
#  ('Pittsburgh0016087', 'Pittsburgh0016087'),
#  ('NYU3662296', 'NYU3662296'),
#  ('KKI1018959', 'KKI1018959'),
#  ('KKI3160561', 'KKI3160561'),
#  ('NYU0010022', 'NYU0010022'),
#  ('Pittsburgh0016046', 'Pittsburgh0016046'),
#  ('NeuroIMAGE9956994', 'NeuroIMAGE9956994'),
#  ('NYU0010037', 'NYU0010037'),
#  ('Peking23993793', 'Peking23993793'),
#  ('Peking14921428', 'Peking14921428'),
#  ('NYU0010039', 'NYU0010039'),
#  ('Peking21177160', 'Peking21177160'),
#  ('Peking13233028', 'Peking13233028'),
#  ('Peking14091983', 'Peking14091983'),
#  ('NYU3653737', 'NYU3653737'),
#  ('NYU0010013', 'NYU0010013'),
#  ('NYU0010085', 'NYU0010085'),
#  ('NYU4084645', 'NYU4084645'),
#  ('KKI1541812', 'KKI1541812'),
#  ('NYU8692452', 'NYU8692452'),
#  ('Peking15193577', 'Peking15193577'),
#  ('KKI3699991', 'KKI3699991'),
#  ('Pittsburgh0016077', 'Pittsburgh0016077'),
#  ('KKI1577042', 'KKI1577042'),
#  ('Pittsburgh0016062', 'Pittsburgh0016062'),
#  ('KKI2026113', 'KKI2026113'),
#  ('KKI1962503', 'KKI1962503'),
#  ('NYU0010008', 'NYU0010008'),
#  ('Peking22559537', 'Peking22559537'),
#  ('NYU0010090', 'NYU0010090'),
#  ('NYU0010006', 'NYU0010006'),
#  ('NeuroIMAGE4239636', 'NeuroIMAGE4239636'),
#  ('NYU0010034', 'NYU0010034'),
#  ('KKI2621228', 'KKI2621228'),
#  ('NYU2741068', 'NYU2741068'),
#  ('KKI4154182', 'KKI4154182'),
#  ('NYU2773205', 'NYU2773205'),
#  ('Peking21875013', 'Peking21875013'),
#  ('Pittsburgh0016050', 'Pittsburgh0016050'),
#  ('Peking21916266', 'Peking21916266'),
#  ('Pittsburgh0016045', 'Pittsburgh0016045'),
#  ('Peking15150328', 'Peking15150328'),
#  ('Peking11561488', 'Peking11561488'),
#  ('KKI3434578', 'KKI3434578'),
#  ('Peking13086074', 'Peking13086074'),
#  ('NYU0010021', 'NYU0010021'),
#  ('Peking11689948', 'Peking11689948'),
#  ('Peking11240299', 'Peking11240299'),
#  ('NYU1471736', 'NYU1471736'),
#  ('NYU0010093', 'NYU0010093'),
#  ('NeuroIMAGE6115230', 'NeuroIMAGE6115230'),
#  ('NeuroIMAGE3888614', 'NeuroIMAGE3888614'),
#  ('KKI2572285', 'KKI2572285'),
#  ('NeuroIMAGE3449233', 'NeuroIMAGE3449233'),
#  ('NYU3679455', 'NYU3679455'),
#  ('NYU2107638', 'NYU2107638'),
#  ('Pittsburgh0016061', 'Pittsburgh0016061'),
#  ('NYU1918630', 'NYU1918630'),
#  ('KKI2018106', 'KKI2018106'),
#  ('Peking13554582', 'Peking13554582'),
#  ('Pittsburgh0016074', 'Pittsburgh0016074'),
#  ('NYU0010010', 'NYU0010010'),
#  ('NYU0010088', 'NYU0010088'),
#  ('KKI1594156', 'KKI1594156'),
#  ('Peking22737106', 'Peking22737106'),
#  ('NYU2260910', 'NYU2260910'),
#  ('NYU0010086', 'NYU0010086'),
#  ('Peking22031422', 'Peking22031422'),
#  ('NYU1511464', 'NYU1511464'),
#  ('Peking13306863', 'Peking13306863'),
#  ('Peking11258069', 'Peking11258069'),
#  ('NYU6568351', 'NYU6568351'),
#  ('NYU0010049', 'NYU0010049'),
#  ('Peking27253183', 'Peking27253183'),
#  ('NYU2054438', 'NYU2054438'),
#  ('KKI3119327', 'KKI3119327'),
#  ('Peking19890726', 'Peking19890726'),
#  ('NYU0010052', 'NYU0010052'),
#  ('Peking12081754', 'Peking12081754'),
#  ('Peking13732101', 'Peking13732101'),
#  ('Pittsburgh0016036', 'Pittsburgh0016036'),
#  ('NYU0010124', 'NYU0010124'),
#  ('NYU1023964', 'NYU1023964'),
#  ('Pittsburgh0016012', 'Pittsburgh0016012'),
#  ('NYU0010100', 'NYU0010100'),
#  ('KKI1996183', 'KKI1996183'),
#  ('Pittsburgh0016084', 'Pittsburgh0016084'),
#  ('Peking12697768', 'Peking12697768'),
#  ('Peking13976121', 'Peking13976121'),
#  ('NYU0010078', 'NYU0010078'),
#  ('KKI1842819', 'KKI1842819'),
#  ('NYU0010076', 'NYU0010076'),
#  ('NYU4187857', 'NYU4187857'),
#  ('NYU0010063', 'NYU0010063'),
#  ('KKI3154996', 'KKI3154996'),
#  ('Peking12703336', 'Peking12703336'),
#  ('NYU4827048', 'NYU4827048'),
#  ('NYU8415034', 'NYU8415034'),
#  ('NYU0010115', 'NYU0010115'),
#  ('Pittsburgh0016009', 'Pittsburgh0016009'),
#  ('NeuroIMAGE3304956', 'NeuroIMAGE3304956'),
#  ('KKI3912996', 'KKI3912996'),
#  ('NYU2306976', 'NYU2306976'),
#  ('KKI2930625', 'KKI2930625'),
#  ('Pittsburgh0016075', 'Pittsburgh0016075'),
#  ('Peking17390867', 'Peking17390867'),
#  ('NeuroIMAGE3959823', 'NeuroIMAGE3959823'),
#  ('Peking22919220', 'Peking22919220'),
#  ('NYU0010087', 'NYU0010087'),
#  ('NYU0010089', 'NYU0010089'),
#  ('NYU0010011', 'NYU0010011'),
#  ('NYU0010004', 'NYU0010004'),
#  ('KKI2138826', 'KKI2138826'),
#  ('NYU0010092', 'NYU0010092'),
#  ('KKI2014113', 'KKI2014113'),
#  ('Pittsburgh0016060', 'Pittsburgh0016060'),
#  ('KKI8628223', 'KKI8628223'),
#  ('Peking11391181', 'Peking11391181'),
#  ('NeuroIMAGE1411495', 'NeuroIMAGE1411495'),
#  ('Peking22377207', 'Peking22377207'),
#  ('Peking11408093', 'Peking11408093'),
#  ('NYU0010020', 'NYU0010020'),
#  ('KKI1779922', 'KKI1779922'),
#  ('Peking23205761', 'Peking23205761'),
#  ('KKI1735881', 'KKI1735881'),
#  ('KKI3713230', 'KKI3713230'),
#  ('NYU0010035', 'NYU0010035'),
#  ('NeuroIMAGE1125505', 'NeuroIMAGE1125505'),
#  ('Pittsburgh0016051', 'Pittsburgh0016051'),
#  ('NYU2950672', 'NYU2950672'),
#  ('NYU5971050', 'NYU5971050'),
#  ('NYU0010062', 'NYU0010062'),
#  ('NYU1995121', 'NYU1995121'),
#  ('Peking21068505', 'Peking21068505'),
#  ('NYU1780174', 'NYU1780174'),
#  ('Pittsburgh0016006', 'Pittsburgh0016006'),
#  ('NYU4164316', 'NYU4164316'),
#  ('Peking27689953', 'Peking27689953'),
#  ('Peking27407032', 'Peking27407032'),
#  ('NYU1435954', 'NYU1435954'),
#  ('NYU0010114', 'NYU0010114'),
#  ('Pittsburgh0016008', 'Pittsburgh0016008'),
#  ('NeuroIMAGE2419464', 'NeuroIMAGE2419464'),
#  ('NeuroIMAGE7504392', 'NeuroIMAGE7504392'),
#  ('Pittsburgh0016085', 'Pittsburgh0016085'),
#  ('NYU0010101', 'NYU0010101'),
#  ('Peking13004580', 'Peking13004580'),
#  ('NYU9578663', 'NYU9578663'),
#  ('NYU1884448', 'NYU1884448'),
#  ('KKI3902469', 'KKI3902469'),
#  ('NYU2821683', 'NYU2821683'),
#  ('NeuroIMAGE3108222', 'NeuroIMAGE3108222'),
#  ('KKI1846346', 'KKI1846346'),
#  ('NYU0010079', 'NYU0010079'),
#  ('Peking23561920', 'Peking23561920'),
#  ('NYU0010053', 'NYU0010053'),
#  ('KKI2299519', 'KKI2299519'),
#  ('Peking22498847', 'Peking22498847'),
#  ('Pittsburgh0016039', 'Pittsburgh0016039'),
#  ('NYU0010125', 'NYU0010125'),
#  ('Peking24265987', 'Peking24265987'),
#  ('Peking29002207', 'Peking29002207'),
#  ('Pittsburgh0016037', 'Pittsburgh0016037'),
#  ('NeuroIMAGE1017176', 'NeuroIMAGE1017176'),
#  ('Pittsburgh0016022', 'Pittsburgh0016022'),
#  ('KKI7415617', 'KKI7415617'),
#  ('Peking12266806', 'Peking12266806'),
#  ('Peking21562298', 'Peking21562298'),
#  ('NYU0010048', 'NYU0010048'),
#  ('Peking26500128', 'Peking26500128'),
#  ('Peking24073815', 'Peking24073815'),
#  ('KKI3813783', 'KKI3813783'),
#  ('Peking21628610', 'Peking21628610'),
#  ('KKI3170319', 'KKI3170319'),
#  ('Peking14475709', 'Peking14475709'),
#  ('NYU8834383', 'NYU8834383'),
#  ('NYU0010102', 'NYU0010102'),
#  ('KKI7774305', 'KKI7774305'),
#  ('Pittsburgh0016086', 'Pittsburgh0016086'),
#  ('NYU9907452', 'NYU9907452'),
#  ('KKI8263351', 'KKI8263351'),
#  ('Peking13739175', 'Peking13739175'),
#  ('Pittsburgh0016010', 'Pittsburgh0016010'),
#  ('KKI1535233', 'KKI1535233'),
#  ('Pittsburgh0016088', 'Pittsburgh0016088'),
#  ('NYU0010117', 'NYU0010117'),
#  ('Peking22884672', 'Peking22884672'),
#  ('NYU2907383', 'NYU2907383'),
#  ('KKI3486975', 'KKI3486975'),
#  ('Peking13587000', 'Peking13587000'),
#  ('NYU1057962', 'NYU1057962'),
#  ('Peking17135128', 'Peking17135128'),
#  ('NYU0010045', 'NYU0010045'),
#  ('Peking12196753', 'Peking12196753'),
#  ('Pittsburgh0016021', 'Pittsburgh0016021'),
#  ('Peking12714224', 'Peking12714224'),
#  ('KKI3917422', 'KKI3917422'),
#  ('NYU3433846', 'NYU3433846'),
#  ('NYU0010126', 'NYU0010126'),
#  ('Pittsburgh0016034', 'Pittsburgh0016034'),
#  ('NYU0010128', 'NYU0010128'),
#  ('NYU1208795', 'NYU1208795'),
#  ('Peking21093743', 'Peking21093743'),
#  ('Peking24055710', 'Peking24055710'),
#  ('Peking19887336', 'Peking19887336'),
#  ('NYU0010050', 'NYU0010050'),
#  ('NeuroIMAGE2671604', 'NeuroIMAGE2671604'),
#  ('Peking12240562', 'Peking12240562'),
#  ('Pittsburgh0016063', 'Pittsburgh0016063'),
#  ('NYU9750701', 'NYU9750701'),
#  ('NYU0010007', 'NYU0010007'),
#  ('NYU0010091', 'NYU0010091'),
#  ('NYU0010009', 'NYU0010009'),
#  ('Peking12367157', 'Peking12367157'),
#  ('NYU0010084', 'NYU0010084'),
#  ('NYU0010012', 'NYU0010012'),
#  ('Pittsburgh0016076', 'Pittsburgh0016076'),
#  ('Peking12535087', 'Peking12535087'),
#  ('Peking14028266', 'Peking14028266'),
#  ('NeuroIMAGE2352986', 'NeuroIMAGE2352986'),
#  ('Pittsburgh0016078', 'Pittsburgh0016078'),
#  ('NeuroIMAGE8387093', 'NeuroIMAGE8387093'),
#  ('Peking14095748', 'Peking14095748'),
#  ('KKI3611827', 'KKI3611827'),
#  ('Pittsburgh0016052', 'Pittsburgh0016052'),
#  ('NYU1320247', 'NYU1320247'),
#  ('Peking22141250', 'Peking22141250'),
#  ('NYU0010038', 'NYU0010038'),
#  ('NYU2030383', 'NYU2030383'),
#  ('Peking13983607', 'Peking13983607'),
#  ('KKI3972956', 'KKI3972956'),
#  ('NYU0010036', 'NYU0010036'),
#  ('NYU0010023', 'NYU0010023'),
#  ('NYU2682736', 'NYU2682736'),
#  ('Peking11282248', 'Peking11282248'),
#  ('Pittsburgh0016049', 'Pittsburgh0016049'),
#  ('Peking23655623', 'Peking23655623'),
#  ('Peking13967265', 'Peking13967265'),
#  ('NYU1875084', 'NYU1875084'),
#  ('Peking11133221', 'Peking11133221'),
#  ('Peking12427408', 'Peking12427408'),
#  ('Pittsburgh0016047', 'Pittsburgh0016047'),
#  ('Pittsburgh0016032', 'Pittsburgh0016032'),
#  ('NYU0010120', 'NYU0010120'),
#  ('NYU0010058', 'NYU0010058'),
#  ('NYU0010056', 'NYU0010056'),
#  ('NYU0010043', 'NYU0010043'),
#  ('Peking11186237', 'Peking11186237'),
#  ('NeuroIMAGE4020830', 'NeuroIMAGE4020830'),
#  ('Pittsburgh0016029', 'Pittsburgh0016029'),
#  ('NeuroIMAGE7446626', 'NeuroIMAGE7446626'),
#  ('Peking23157406', 'Peking23157406'),
#  ('NeuroIMAGE3190461', 'NeuroIMAGE3190461'),
#  ('NYU6206397', 'NYU6206397'),
#  ('Pittsburgh0016027', 'Pittsburgh0016027'),
#  ('Peking12408774', 'Peking12408774'),
#  ('NYU3349423', 'NYU3349423'),
#  ('NYU0010069', 'NYU0010069'),
#  ('NYU0010072', 'NYU0010072'),
#  ('KKI4275075', 'KKI4275075'),
#  ('NYU0010104', 'NYU0010104'),
#  ('Peking12123983', 'Peking12123983'),
#  ('Pittsburgh0016018', 'Pittsburgh0016018'),
#  ('Pittsburgh0016080', 'Pittsburgh0016080'),
#  ('NYU1359325', 'NYU1359325'),
#  ('Pittsburgh0016041', 'Pittsburgh0016041'),
#  ('NYU2497695', 'NYU2497695'),
#  ('KKI1988015', 'KKI1988015'),
#  ('Peking13269608', 'Peking13269608'),
#  ('Peking13212536', 'Peking13212536'),
#  ('NeuroIMAGE2074737', 'NeuroIMAGE2074737'),
#  ('Peking21117299', 'Peking21117299'),
#  ('KKI9922944', 'KKI9922944'),
#  ('NeuroIMAGE4134561', 'NeuroIMAGE4134561'),
#  ('KKI2601925', 'KKI2601925'),
#  ('KKI2104012', 'KKI2104012'),
#  ('NYU2230510', 'NYU2230510'),
#  ('KKI1266183', 'KKI1266183'),
#  ('Peking13889095', 'Peking13889095'),
#  ('Peking12538839', 'Peking12538839'),
#  ('Peking21809715', 'Peking21809715'),
#  ('KKI2740232', 'KKI2740232'),
#  ('NYU0010082', 'NYU0010082'),
#  ('KKI1652369', 'KKI1652369'),
#  ('Peking11805037', 'Peking11805037'),
#  ('Pittsburgh0016070', 'Pittsburgh0016070'),
#  ('NYU2983819', 'NYU2983819'),
#  ('NYU9326955', 'NYU9326955'),
#  ('NYU8915162', 'NYU8915162'),
#  ('Pittsburgh0016065', 'Pittsburgh0016065'),
#  ('NYU0010097', 'NYU0010097'),
#  ('NYU2991307', 'NYU2991307'),
#  ('KKI1043241', 'KKI1043241'),
#  ('KKI2081148', 'KKI2081148'),
#  ('NYU0010099', 'NYU0010099'),
#  ('NYU0010001', 'NYU0010001'),
#  ('Peking23910672', 'Peking23910672'),
#  ('Peking12897046', 'Peking12897046'),
#  ('NYU0010033', 'NYU0010033'),
#  ('NYU3542588', 'NYU3542588'),
#  ('NYU1283494', 'NYU1283494'),
#  ('Pittsburgh0016059', 'Pittsburgh0016059'),
#  ('Peking29578631', 'Peking29578631'),
#  ('Peking21050975', 'Peking21050975'),
#  ('Pittsburgh0016057', 'Pittsburgh0016057'),
#  ('Peking21341865', 'Peking21341865'),
#  ('NeuroIMAGE2574674', 'NeuroIMAGE2574674'),
#  ('NYU4116166', 'NYU4116166'),
#  ('Pittsburgh0016042', 'Pittsburgh0016042'),
#  ('Peking23994098', 'Peking23994098'),
#  ('Peking11879542', 'Peking11879542'),
#  ('Peking24225073', 'Peking24225073'),
#  ('NYU1740607', 'NYU1740607'),
#  ('NeuroIMAGE1538046', 'NeuroIMAGE1538046'),
#  ('KKI2344857', 'KKI2344857'),
#  ('NYU0010028', 'NYU0010028'),
#  ('NYU0010026', 'NYU0010026'),
#  ('Peking12833684', 'Peking12833684'),
#  ('NeuroIMAGE2961243', 'NeuroIMAGE2961243'),
#  ('Peking13262042', 'Peking13262042'),
#  ('KKI3972472', 'KKI3972472'),
#  ('NYU0010094', 'NYU0010094'),
#  ('NYU0010002', 'NYU0010002'),
#  ('Pittsburgh0016066', 'Pittsburgh0016066'),
#  ('Peking17093319', 'Peking17093319'),
#  ('Peking18838009', 'Peking18838009'),
#  ('Peking21494102', 'Peking21494102'),
#  ('Pittsburgh0016068', 'Pittsburgh0016068'),
#  ('NYU1854959', 'NYU1854959'),
#  ('NeuroIMAGE3566449', 'NeuroIMAGE3566449'),
#  ('Peking13239413', 'Peking13239413'),
#  ('Pittsburgh0016073', 'Pittsburgh0016073'),
#  ('NYU3235580', 'NYU3235580'),
#  ('NYU4154672', 'NYU4154672'),
#  ('NYU8009688', 'NYU8009688'),
#  ('NYU0010017', 'NYU0010017'),
#  ('Peking12174595', 'Peking12174595'),
#  ('NYU0010081', 'NYU0010081'),
#  ('NYU0010019', 'NYU0010019'),
#  ('NYU1099481', 'NYU1099481'),
#  ('NYU0010040', 'NYU0010040'),
#  ('Peking19210521', 'Peking19210521'),
#  ('KKI2917777', 'KKI2917777'),
#  ('NeuroIMAGE8409791', 'NeuroIMAGE8409791'),
#  ('NYU2996531', 'NYU2996531'),
#  ('NYU4060823', 'NYU4060823'),
#  ('Pittsburgh0016031', 'Pittsburgh0016031'),
#  ('Peking23494778', 'Peking23494778'),
#  ('NYU0010123', 'NYU0010123'),
#  ('KKI2558999', 'KKI2558999'),
#  ('Pittsburgh0016083', 'Pittsburgh0016083'),
#  ('NYU0010107', 'NYU0010107'),
#  ('Peking24075719', 'Peking24075719'),
#  ('Peking11791543', 'Peking11791543'),
#  ('Peking11056121', 'Peking11056121'),
#  ('NYU0010071', 'NYU0010071'),
#  ('NYU0010064', 'NYU0010064'),
#  ('Peking23308331', 'Peking23308331'),
#  ('Peking21860323', 'Peking21860323'),
#  ('NYU0010112', 'NYU0010112'),
#  ('NYU1000804', 'NYU1000804'),
#  ('KKI8083695', 'KKI8083695'),
#  ('KKI3884955', 'KKI3884955'),
#  ('Peking22296326', 'Peking22296326')]

# %%
connection_features = pd.DataFrame(features, columns=feature_names, index=subjects)

# %%
connection_features["age"] = metadata_sorted["age"].values
connection_features["gender"] = [1 if g == "Male" else 0 for g in metadata_sorted["gender"].values]
connection_features["adhd"] = metadata_sorted["adhd"].values

# %%
# sort so adhd, age, gender columns are first
connection_features = connection_features[["adhd", "age", "gender"] + list(connection_features.columns[:-3])]

# %%
connection_features
# Out:
#                 adhd    age  gender  RFP_0_to_BS_0  RFP_1_to_BS_0  \
# NYU1567356         0   8.91       0       0.000000       0.000000
# Peking12106109     0   9.92       0       0.285667       0.000000
# Peking23562883     0  11.25       1       0.219172       0.232962
# Peking11139030     0  11.33       0       0.401079       0.116047
# NYU0010080         0  17.86       0       0.000000       0.000000
# ...              ...    ...     ...            ...            ...
# NYU0010112         0  14.79       1       0.423015       0.000000
# NYU1000804         0   7.29       1       0.000000       0.076278
# KKI8083695         0   8.62       1       0.153625       0.000000
# KKI3884955         0  11.84       1       0.615978       0.000000
# Peking22296326     0  12.17       1       0.031750       0.000000
#
#                 RFP_1_to_RFP_0  RLG_0_to_BS_0  RLG_0_to_RFP_0  RLG_0_to_RFP_1  \
# NYU1567356            0.000000       0.173291        0.000000        0.000000
# Peking12106109        0.000000       0.708364        0.402485        0.000000
# Peking23562883        0.034964       0.012224        0.153660        0.000000
# Peking11139030        0.007259       0.000000        0.261506        0.126393
# NYU0010080            0.184725       0.259696        0.000000        0.000000
# ...                        ...            ...             ...             ...
# NYU0010112            0.000000       0.000000        0.000000        0.459780
# NYU1000804            0.000000       0.407724        0.000000        0.627842
# KKI8083695            0.085031       0.000000        0.223546        0.075935
# KKI3884955            0.000000       0.000000        0.000000        0.020968
# Peking22296326        0.116226       0.000000        0.055984        0.000000
#
#                 RIC_0_to_BS_0  ...  RIFGpo_0_to_LITGpd_1  \
# NYU1567356           0.000000  ...              0.000000
# Peking12106109       0.000000  ...              0.240733
# Peking23562883       0.287462  ...              0.173660
# Peking11139030       0.429395  ...              0.000000
# NYU0010080           0.397702  ...              0.234918
# ...                       ...  ...                   ...
# NYU0010112           0.000000  ...              0.138709
# NYU1000804           0.283502  ...              0.504621
# KKI8083695           0.207574  ...              0.074787
# KKI3884955           0.000000  ...              0.156700
# Peking22296326       0.000000  ...              0.283792
#
#                 RIFGpo_0_to_LLOCid_2  RIFGpo_0_to_RCI_1  RIFGpo_0_to_LLOCsd_4  \
# NYU1567356                  0.000000           0.001152              0.000000
# Peking12106109              0.000000           0.217633              0.000000
# Peking23562883              0.000000           0.000000              0.022333
# Peking11139030              0.000000           0.326461              0.000000
# NYU0010080                  0.000000           0.124058              0.000000
# ...                              ...                ...                   ...
# NYU0010112                  0.160208           0.000000              0.000000
# NYU1000804                  0.000000           0.000000              0.000000
# KKI8083695                  0.000000           0.000000              0.000000
# KKI3884955                  0.000000           0.000000              0.000000
# Peking22296326              0.199679           0.000000              0.000000
#
#                 RIFGpo_0_to_RLOCsd_4  RIFGpo_0_to_RTP_3  RIFGpo_0_to_RCII_0  \
# NYU1567356                  0.000000           0.084797            0.000000
# Peking12106109              0.000000           0.416794            0.000000
# Peking23562883              0.000000           0.000000            0.000000
# Peking11139030              0.000000           0.437491            0.000000
# NYU0010080                  0.000000           0.130253            0.000000
# ...                              ...                ...                 ...
# NYU0010112                  0.062983           0.165115            0.000000
# NYU1000804                  0.212321           0.000000            0.000000
# KKI8083695                  0.288287           0.000000            0.000000
# KKI3884955                  0.210738           0.280571            0.000000
# Peking22296326              0.000000           0.469283            0.065851
#
#                 RIFGpo_0_to_LMTGpd_1  RIFGpo_0_to_LFP_8  RIFGpo_0_to_RCGad_2
# NYU1567356                  0.000000           0.000000             0.000000
# Peking12106109              0.334937           0.083589             0.073926
# Peking23562883              0.267343           0.000000             0.000000
# Peking11139030              0.000000           0.000000             0.000000
# NYU0010080                  0.020319           0.000000             0.065947
# ...                              ...                ...                  ...
# NYU0010112                  0.000000           0.000000             0.000000
# NYU1000804                  0.000000           0.000000             0.000000
# KKI8083695                  0.000000           0.000000             0.313964
# KKI3884955                  0.000000           0.000000             0.000000
# Peking22296326              0.000000           0.000000             0.337313
#
# [520 rows x 17958 columns]

# %%
save_connection_features = True
if save_connection_features:
    with open("all_connection_features.pkl", "wb") as f:
        pkl.dump(connection_features, f)
